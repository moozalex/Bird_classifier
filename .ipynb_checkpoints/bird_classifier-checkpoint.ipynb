# %% [markdown]
# # Bird Classifier
#
# About Data: An image dataset with photos of 200 bird species (mostly North American); it can also be used for localization. Number of categories: 200; Number of images: 11,788; Annotations per image: 15 Part Locations, 312 Binary Attributes, 1 Bounding Box
#
# By: Alex Moozhayil and David Le

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *
from fastai.metrics import error_rate
import pickle

# %%
bs = 32

# %% [markdown]
# ### Looking at the Data

# %%
path = untar_data(URLs.CUB_200_2011)
path
# Out:
# PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011')

# %%
path.ls()
# Out:
# [PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011/parts'),
#  PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011/bounding_boxes.txt'),
#  PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011/image_class_labels.txt'),
#  PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011/images'),
#  PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011/README'),
#  PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011/images.txt'),
#  PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011/attributes'),
#  PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011/classes.txt'),
#  PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011/train_test_split.txt')]

# %%
path_img = path/'images'

# %%
p = Path(path_img)
dirs = [x for x in p.iterdir() if x.is_dir()]
fnames = [get_image_files(y) for y in dirs]
fnames = [item for sublist in fnames for item in sublist]
fnames[:5]
# Out:
# [PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011/images/197.Marsh_Wren/Marsh_Wren_0103_188483.jpg'),
#  PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011/images/197.Marsh_Wren/Marsh_Wren_0055_188123.jpg'),
#  PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011/images/197.Marsh_Wren/Marsh_Wren_0004_188188.jpg'),
#  PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011/images/197.Marsh_Wren/Marsh_Wren_0134_188213.jpg'),
#  PosixPath('/home/alexbm92/.fastai/data/CUB_200_2011/images/197.Marsh_Wren/Marsh_Wren_0069_188776.jpg')]

# %%
np.random.seed(2)
pat = r'/([^/]+)_\d+_\d+.jpg$'

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=224, bs=bs).normalize(imagenet_stats)

# %%
data.show_batch(rows=3, figsize=(7,6))

# %% [markdown]
# ## Training: resnet34

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (5): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (6): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (3): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (4): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (5): Bottleneck(
#         (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#     (7): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (downsample): Sequential(
#           (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#       (2): Bottleneck(
#         (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(4096, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=4096, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=200, bias=True)
#   )
# )

# %%
learn.fit_one_cycle(7)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.286592</td>
#       <td>2.005363</td>
#       <td>0.521001</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.235296</td>
#       <td>1.518573</td>
#       <td>0.401782</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.737433</td>
#       <td>1.308821</td>
#       <td>0.361052</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.327756</td>
#       <td>1.076449</td>
#       <td>0.297836</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.973092</td>
#       <td>0.970747</td>
#       <td>0.279168</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.749592</td>
#       <td>0.906500</td>
#       <td>0.254137</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.637124</td>
#       <td>0.891718</td>
#       <td>0.245227</td>
#       <td>00:57</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %% [markdown]
# ## Results

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses, idxs = interp.top_losses()

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('Brandt_Cormorant', 'Pelagic_Cormorant', 6),
#  ('Slaty_Backed_Gull', 'Western_Gull', 6),
#  ('Yellow_Bellied_Flycatcher', 'Acadian_Flycatcher', 6),
#  ('American_Crow', 'Common_Raven', 4),
#  ('Barn_Swallow', 'Cliff_Swallow', 4),
#  ('Chuck_Will_Widow', 'Whip_Poor_Will', 4),
#  ('Common_Raven', 'American_Crow', 4),
#  ('Common_Tern', 'Artic_Tern', 4),
#  ('Fish_Crow', 'American_Crow', 4),
#  ('Green_Kingfisher', 'Belted_Kingfisher', 4),
#  ('Olive_Sided_Flycatcher', 'Western_Wood_Pewee', 4),
#  ('Acadian_Flycatcher', 'Yellow_Bellied_Flycatcher', 3),
#  ('Blue_Grosbeak', 'Indigo_Bunting', 3),
#  ('Boat_Tailed_Grackle', 'Rusty_Blackbird', 3),
#  ('California_Gull', 'Ring_Billed_Gull', 3),
#  ('Common_Tern', 'Caspian_Tern', 3),
#  ('Common_Tern', 'Forsters_Tern', 3),
#  ('Glaucous_Winged_Gull', 'Ring_Billed_Gull', 3),
#  ('Least_Flycatcher', 'Acadian_Flycatcher', 3),
#  ('Mangrove_Cuckoo', 'Yellow_Billed_Cuckoo', 3),
#  ('Nelson_Sharp_Tailed_Sparrow', 'Seaside_Sparrow', 3),
#  ('Pomarine_Jaeger', 'Long_Tailed_Jaeger', 3),
#  ('Ring_Billed_Gull', 'Glaucous_Winged_Gull', 3),
#  ('Ruby_Throated_Hummingbird', 'Rufous_Hummingbird', 3),
#  ('Sooty_Albatross', 'Black_Footed_Albatross', 3),
#  ('Western_Wood_Pewee', 'Olive_Sided_Flycatcher', 3),
#  ('American_Crow', 'Brewer_Blackbird', 2),
#  ('American_Crow', 'Fish_Crow', 2),
#  ('Anna_Hummingbird', 'Ruby_Throated_Hummingbird', 2),
#  ('Artic_Tern', 'Common_Tern', 2),
#  ('Baltimore_Oriole', 'Hooded_Oriole', 2),
#  ('Baltimore_Oriole', 'Pine_Warbler', 2),
#  ('Black_Footed_Albatross', 'Northern_Fulmar', 2),
#  ('Brewer_Blackbird', 'Shiny_Cowbird', 2),
#  ('Carolina_Wren', 'Bewick_Wren', 2),
#  ('Caspian_Tern', 'Artic_Tern', 2),
#  ('Caspian_Tern', 'Elegant_Tern', 2),
#  ('Chestnut_Sided_Warbler', 'Magnolia_Warbler', 2),
#  ('Chipping_Sparrow', 'White_Throated_Sparrow', 2),
#  ('Clay_Colored_Sparrow', 'Brewer_Sparrow', 2),
#  ('Clay_Colored_Sparrow', 'Grasshopper_Sparrow', 2),
#  ('Crested_Auklet', 'Parakeet_Auklet', 2),
#  ('Elegant_Tern', 'Caspian_Tern', 2),
#  ('Fish_Crow', 'Common_Raven', 2),
#  ('Forsters_Tern', 'Common_Tern', 2),
#  ('Grasshopper_Sparrow', 'Baird_Sparrow', 2),
#  ('Great_Crested_Flycatcher', 'Acadian_Flycatcher', 2),
#  ('Herring_Gull', 'Western_Gull', 2),
#  ('Hooded_Warbler', 'Wilson_Warbler', 2),
#  ('Horned_Lark', 'Black_Throated_Sparrow', 2),
#  ('House_Wren', 'Winter_Wren', 2),
#  ('Indigo_Bunting', 'Blue_Grosbeak', 2),
#  ('Le_Conte_Sparrow', 'Nelson_Sharp_Tailed_Sparrow', 2),
#  ('Long_Tailed_Jaeger', 'Pomarine_Jaeger', 2),
#  ('Mourning_Warbler', 'Nashville_Warbler', 2),
#  ('Nashville_Warbler', 'Painted_Bunting', 2),
#  ('Nighthawk', 'Whip_Poor_Will', 2),
#  ('Northern_Waterthrush', 'Louisiana_Waterthrush', 2),
#  ('Orange_Crowned_Warbler', 'Tennessee_Warbler', 2),
#  ('Palm_Warbler', 'Prairie_Warbler', 2),
#  ('Pine_Warbler', 'Yellow_Throated_Vireo', 2),
#  ('Pomarine_Jaeger', 'Slaty_Backed_Gull', 2),
#  ('Ringed_Kingfisher', 'Belted_Kingfisher', 2),
#  ('Rock_Wren', 'Winter_Wren', 2),
#  ('Rusty_Blackbird', 'American_Crow', 2),
#  ('Slaty_Backed_Gull', 'Northern_Fulmar', 2),
#  ('Song_Sparrow', 'Fox_Sparrow', 2),
#  ('Song_Sparrow', 'Savannah_Sparrow', 2),
#  ('Song_Sparrow', 'Seaside_Sparrow', 2),
#  ('Tennessee_Warbler', 'Philadelphia_Vireo', 2),
#  ('Tree_Sparrow', 'Chipping_Sparrow', 2),
#  ('Tree_Sparrow', 'House_Sparrow', 2),
#  ('Warbling_Vireo', 'Philadelphia_Vireo', 2),
#  ('Western_Grebe', 'Horned_Grebe', 2),
#  ('Western_Gull', 'California_Gull', 2),
#  ('Yellow_Billed_Cuckoo', 'Black_Billed_Cuckoo', 2)]

# %% [raw]
# learn.export('trained_model.pkl')
